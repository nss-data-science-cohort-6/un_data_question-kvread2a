# %% [markdown]
# # Question 3 - import packages

# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %matplotlib inline

# %% [markdown]
#     # Question 4a - read GDP dataset into notebook

# %%
gdp_df = pd.read_csv("../data/gdp_per_capita.csv")
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %% [markdown]
# gdp_df

# %% [markdown]
# # Question 4b - display first 10 rows

# %%
gdp_df[0:10]
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN
# 6     Afghanistan  2013  2116.465454              NaN
# 7     Afghanistan  2012  2075.491747              NaN
# 8     Afghanistan  2011  1904.559799              NaN
# 9     Afghanistan  2010  1957.029338              NaN

# %% [markdown]
# # Question 4c - display last 5 rows

# %%
gdp_df.iloc[-5:]
# Out:
#      Country or Area                                      Year        Value  \
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6865              NaN
# 6866              NaN
# 6867              NaN
# 6868              NaN
# 6869              NaN

# %% [markdown]
# # Problem - last 2 rows need to be removed

# %%
# Question 4d - Redo read_csv() call and remove last 2 rows

# %%
gdp_df = pd.read_csv("../data/gdp_per_capita.csv", skipfooter=2, engine='python')
gdp_df.iloc[-5:]
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %%
gdp_df.iloc[-5:, 0:2]
# Out:
#      Country or Area  Year
# 6863        Zimbabwe  1994
# 6864        Zimbabwe  1993
# 6865        Zimbabwe  1992
# 6866        Zimbabwe  1991
# 6867        Zimbabwe  1990

# %%
gdp_df.iloc[4:10, -2:]
# Out:
#          Value  Value Footnotes
# 4  2068.265904              NaN
# 5  2102.385234              NaN
# 6  2116.465454              NaN
# 7  2075.491747              NaN
# 8  1904.559799              NaN
# 9  1957.029338              NaN

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'], axis=1)

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area':'Country','Value':'GDP_Per_Capita'})
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
gdp_df.shape
# Out:
# (6868, 3)

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   object
#  1   Year            6868 non-null   int64
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 161.1+ KB

# %%
gdp_df = gdp_df.astype({"Country": "category"})

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   category
#  1   Year            6868 non-null   int64
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: category(1), float64(1), int64(1)
# memory usage: 130.8 KB

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
gdp_df["Year"].value_counts()
# Out:
# 2017    238
# 2016    238
# 2015    238
# 2014    238
# 2013    238
# 2012    237
# 2011    237
# 2018    237
# 2010    236
# 2009    236
# 2008    235
# 2007    235
# 2006    235
# 2005    234
# 2004    234
# 2003    233
# 2002    233
# 2001    232
# 2000    231
# 2019    231
# 1999    224
# 1998    223
# 1997    223
# 1996    221
# 1995    221
# 1994    214
# 1993    212
# 1992    209
# 1991    208
# 1990    207
# Name: Year, dtype: int64

# %%
gdp_df["Country"].value_counts()
# Out:
# Lebanon                      30
# Middle income                30
# Morocco                      30
# Mozambique                   30
# Myanmar                      30
#                              ..
# Nauru                        16
# Cayman Islands               13
# Sint Maarten (Dutch part)    10
# Turks and Caicos Islands      9
# Djibouti                      7
# Name: Country, Length: 238, dtype: int64

# %%
gdp_2014 = gdp_df[gdp_df["Year"]==2014]

# %%
gdp_2014
# Out:
#                   Country  Year  GDP_Per_Capita
# 5             Afghanistan  2014     2102.385234
# 23                Albania  2014    11623.866679
# 53                Algeria  2014    11512.705405
# 83                 Angola  2014     8239.828837
# 113   Antigua and Barbuda  2014    18104.241470
# ...                   ...   ...             ...
# 6727              Vietnam  2014     6098.489609
# 6757   West Bank and Gaza  2014     5967.073437
# 6783                World  2014    15189.648507
# 6813               Zambia  2014     3450.046561
# 6843             Zimbabwe  2014     2955.240287
#
# [238 rows x 3 columns]

# %%
gdp_2014["GDP_Per_Capita"].describe()
# Out:
# count       238.000000
# mean      19766.710348
# std       20983.869623
# min         822.610458
# 25%        4753.110934
# 50%       12209.385755
# 75%       26803.610474
# max      156514.133850
# Name: GDP_Per_Capita, dtype: float64

# %%
gdp_2014["GDP_Per_Capita"].hist(bins=25)
# Out:
# <AxesSubplot:>

# %%
gdp_2014["Country"].head()
# Out:
# 5              Afghanistan
# 23                 Albania
# 53                 Algeria
# 83                  Angola
# 113    Antigua and Barbuda
# Name: Country, dtype: category
# Categories (238, object): ['Afghanistan', 'Albania', 'Algeria', 'Angola', ..., 'West Bank and Gaza', 'World', 'Zambia', 'Zimbabwe']

# %%
gdp_2014["Country"].tail()
# Out:
# 6727               Vietnam
# 6757    West Bank and Gaza
# 6783                 World
# 6813                Zambia
# 6843              Zimbabwe
# Name: Country, dtype: category
# Categories (238, object): ['Afghanistan', 'Albania', 'Algeria', 'Angola', ..., 'West Bank and Gaza', 'World', 'Zambia', 'Zimbabwe']

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
gdp_pivoted = gdp_df.pivot(index='Country', columns='Year', values='GDP_Per_Capita')
gdp_pivoted = gdp_pivoted.dropna()
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# Arab World            9694.667544   9651.626577   9933.531454   9927.649928
# ...                           ...           ...           ...           ...
# Vanuatu               2888.309393   2897.327707   2886.920558   2824.882319
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
gdp_pivoted['Percent_Change']=100*(gdp_pivoted[2017] - gdp_pivoted[1990])/gdp_pivoted[1990]

# %%
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# Arab World            9694.667544   9651.626577   9933.531454   9927.649928
# ...                           ...           ...           ...           ...
# Vanuatu               2888.309393   2897.327707   2886.920558   2824.882319
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
gdp_pivoted[gdp_pivoted['Percent_Change']<0].shape[0]
# Out:
# 17

# %%
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# Arab World            9694.667544   9651.626577   9933.531454   9927.649928
# ...                           ...           ...           ...           ...
# Vanuatu               2888.309393   2897.327707   2886.920558   2824.882319
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
gdp_pivoted[[
# Out:
# Year
# Percent_Change    2068.404561
# dtype: float64
